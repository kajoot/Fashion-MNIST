# %% [markdown]
# <a href="https://colab.research.google.com/github/kajoot/Fashion-MNIST/blob/main/Fashion_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf

# %% [markdown]
# ***Loading data***

# %%
fashion_mnist = tf.keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()
# Out:
# ...
# 4431872/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# ***Checking data***

# %%
Labels = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
import matplotlib 
import matplotlib.pyplot as plt 

plt.figure(figsize=(8,8))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    plt.xlabel(Labels[train_labels[i]])
plt.show()

# %% [markdown]
# ***Normlizing data***

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

# %% [markdown]
# ***Model***

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(10,activation='softmax')
])
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  flatten_4 (Flatten)         (None, 784)               0
#
#  dense_8 (Dense)             (None, 128)               100480
#
#  dense_9 (Dense)             (None, 10)                1290
#
# ...
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ***Model Training***

# %%
model.fit(train_images, train_labels, epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 4s 2ms/step - loss: 2.3028 - accuracy: 0.0990
# Epoch 2/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 2.3028 - accuracy: 0.0979
# Epoch 3/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 2.3028 - accuracy: 0.0995
# Epoch 4/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 2.3028 - accuracy: 0.0983
# Epoch 5/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 2.3028 - accuracy: 0.0976
# Epoch 6/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 2.3027 - accuracy: 0.0987
# Epoch 7/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 2.3028 - accuracy: 0.0992
# Epoch 8/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 2.3028 - accuracy: 0.0989
# Epoch 9/10
# 1875/1875 [==============================] - 3s 2ms/step - loss: 2.3028 - accuracy: 0.0998
# Epoch 10/10
# ...

# %% [markdown]
# ***Model Evaluation***

# %%
test_acc = model.evaluate(test_images,  test_labels)
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 2.3026 - accuracy: 0.1000
